# %% [markdown]
# <a href="https://colab.research.google.com/github/Emanuele05Lima/Python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Aula 1

# %%
ano = "IV"
print (ano, " competição de programação dá Start")

# %% [markdown]
# Aula 2

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# Aula 3

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_Anderson = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o numero de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas_Anderson2 = figurinhas_extras * 2

print(f"Anderson recebeu {figurinhas_Anderson} figurinhas")
print(f"Anderson recebeu {figurinhas_Anderson2} figurinhas extras")
# Out:
# Digite o total de figurinhas: 20
# Digite o número de amigos: 5
# Digite o numero de figurinhas extras: 2
# Anderson recebeu 4 figurinhas
# Anderson recebeu 0 figurinhas extras

# %% [markdown]
# #**Aula 4** ✴ ❤ 💓
# ##**Dia de Prova**

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 0
# B

# %% [markdown]
# Aula 5 - cálculo de IMC ✅ ⏳ ⚡

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")

# %% [markdown]
# **Aula 6 - Tabuada ✈ ⚛ ⛓**

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# **Aula 7 - Idade ⛅**

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
   idade_filho3 = idade_monica - idade_filho1 - idade_filho2
   idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
return idade_filho3, idade_maxima
resultado = calcula_idade_maior(68, 12, 30)
print(resultado)

# %% [markdown]
# #**Aula 8** ⛄ ⛺  💓

# %%
print("Sou seu assistente virtual \n")
nome = input("Seu nome: ")
print(f"Olá {nome}, em que posso ajudar?")
resposta = input ("Qual assunto você deseja tratar? Matemática, Python ou Javascript: ") . lower()
if resposta=="python":
  print("Ótimo, vamos falar sobre Python! ")
  print("O Python é aplicado em diversas áreas como desenvolvimento web, ciência de dados e aprendizado de máquina, automação de tarefas, e desenvolvimento de software.")
elif resposta=="matemática":
  print(" A matemática usa a radiciação, que é a operação inversa da potenciação, para resolver raízes. ")
  print("Perfeito, vamos resolver umas questões de matemática!")
elif resposta=="javascript":
  print("JavaScript é uma linguagem de programação de alto nível, leve e interpretada, usada principalmente para adicionar interatividade e dinamismo a páginas da web.")
  print("Que legal, vamos conversar sobre javascript!")
else:
  print("Hum, não sei falar sobre esse assunto ")
# Out:
# Sou seu assistente virtual
#
# Seu nome: manu
# Olá manu, em que posso ajudar?
# Qual assunto você deseja tratar? Matemática, Python ou Javascript: python
# Ótimo, vamos falar sobre Python!
# O Python é aplicado em diversas áreas como desenvolvimento web, ciência de dados e aprendizado de máquina, automação de tarefas, e desenvolvimento de software.

# %% [markdown]
# **Aula 9**  **Listas** ✨ ⛳ 🚲

# %%
import random
dica = [
"Acredite em você, o resto vem com o tempo! 💪",
"Cada passo dado é um passo mais perto do seu objetivo! 🚶‍♂️",
"Não pare até se orgulhar! 🌟",
"Desafios são oportunidades disfarçadas! 💥",
"Você é mais forte do que pensa! 🦸‍♂️",
"A persistência é a chave para o sucesso! 🔑",
"O impossível é só uma opinião! 🚀",
"Acredite que você pode e já está meio caminho andado! 🌈",
"O sucesso começa quando você decide tentar! 🎯",
"Nunca é tarde para começar de novo! 🌱",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar").lower()

  if pedido == "dica":
    dica = random.choice(dica)
    print(f"Dica: == {dica}")
  elif pedido == "sair":
    print("Até mais")
    break
  else:
    print("Comando não reconhecido. tente novamente.")
